# %%
# Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time

# %%
# Create list for weather data
city_data = []

# Print the beginning 
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Set counters
record_count = 1
set_count = 1

# Create url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create the 2000 random coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create cities list 
cities = []

# Find nearest cities using coordinate list using citipy
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    

# Count of unique cities
len(cities)
# Out:
# 727

# %%
# Loop through cities lists 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Create API request for each city 
    try:
       
        # Add JSON
        city_weather = requests.get(city_url).json()
                # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        #In the case of an error
    except: 
        print("City not found. Skipping")
        pass

# Complete data retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | clyde river
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | flinders
# Processing Record 4 of Set 1 | geraldton
# Processing Record 5 of Set 1 | laguna
# Processing Record 6 of Set 1 | gorele
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | ostrovnoy
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | bonavista
# Processing Record 11 of Set 1 | tasiilaq
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | saint george
# Processing Record 14 of Set 1 | atar
# Processing Record 15 of Set 1 | carnarvon
# Processing Record 16 of Set 1 | ponta do sol
# Processing Record 17 of Set 1 | meyungs
# City not found. Skipping
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | camana
# Processing Record 20 of Set 1 | kavieng
# Processing Record 21 of Set 1 | ilulissat
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | champerico
# Processing Record 24 of Set 1 | sao jose da coroa grande
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | east london
# Processing Record 27 of Set 1 | kahului
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | espanola
# Processing Record 30 of Set 1 | nanortalik
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | cabo san lucas
# Processing Record 33 of Set 1 | thompson
# Processing Record 34 of Set 1 | kaitangata
# Processing Record 35 of Set 1 | saint-philippe
# Processing Record 36 of Set 1 | mar del plata
# Processing Record 37 of Set 1 | itaituba
# Processing Record 38 of Set 1 | staszow
# Processing Record 39 of Set 1 | sangar
# Processing Record 40 of Set 1 | santa rosa
# Processing Record 41 of Set 1 | tessalit
# Processing Record 42 of Set 1 | rawannawi
# City not found. Skipping
# Processing Record 43 of Set 1 | victoria
# Processing Record 44 of Set 1 | takoradi
# Processing Record 45 of Set 1 | glace bay
# Processing Record 46 of Set 1 | san javier
# Processing Record 47 of Set 1 | pevek
# Processing Record 48 of Set 1 | tsihombe
# City not found. Skipping
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | marsh harbour
# Processing Record 1 of Set 2 | bluff
# Processing Record 2 of Set 2 | amderma
# City not found. Skipping
# Processing Record 3 of Set 2 | iracoubo
# Processing Record 4 of Set 2 | kabin buri
# Processing Record 5 of Set 2 | georgetown
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | busselton
# Processing Record 8 of Set 2 | grand river south east
# City not found. Skipping
# Processing Record 9 of Set 2 | bull savanna
# Processing Record 10 of Set 2 | sur
# Processing Record 11 of Set 2 | mahebourg
# Processing Record 12 of Set 2 | lauria
# Processing Record 13 of Set 2 | khatanga
# Processing Record 14 of Set 2 | isa khel
# Processing Record 15 of Set 2 | talnakh
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | tibacuy
# Processing Record 19 of Set 2 | morondava
# Processing Record 20 of Set 2 | tuktoyaktuk
# Processing Record 21 of Set 2 | boende
# Processing Record 22 of Set 2 | barrow
# Processing Record 23 of Set 2 | hermanus
# Processing Record 24 of Set 2 | taolanaro
# City not found. Skipping
# Processing Record 25 of Set 2 | mayor pablo lagerenza
# Processing Record 26 of Set 2 | praia da vitoria
# Processing Record 27 of Set 2 | sitka
# Processing Record 28 of Set 2 | cidreira
# Processing Record 29 of Set 2 | souillac
# Processing Record 30 of Set 2 | mount gambier
# Processing Record 31 of Set 2 | wilmington
# Processing Record 32 of Set 2 | samusu
# City not found. Skipping
# Processing Record 33 of Set 2 | illoqqortoormiut
# City not found. Skipping
# Processing Record 34 of Set 2 | dunga bunga
# Processing Record 35 of Set 2 | ocampo
# Processing Record 36 of Set 2 | nizhneyansk
# City not found. Skipping
# Processing Record 37 of Set 2 | hobart
# Processing Record 38 of Set 2 | airai
# Processing Record 39 of Set 2 | port elizabeth
# Processing Record 40 of Set 2 | jamestown
# Processing Record 41 of Set 2 | sao felix do xingu
# Processing Record 42 of Set 2 | bathsheba
# Processing Record 43 of Set 2 | aklavik
# Processing Record 44 of Set 2 | lander
# Processing Record 45 of Set 2 | baykit
# Processing Record 46 of Set 2 | itoman
# Processing Record 47 of Set 2 | sabang
# Processing Record 48 of Set 2 | hithadhoo
# Processing Record 49 of Set 2 | ribeira grande
# Processing Record 50 of Set 2 | katsuura
# Processing Record 1 of Set 3 | chicama
# Processing Record 2 of Set 3 | barentsburg
# City not found. Skipping
# Processing Record 3 of Set 3 | myre
# Processing Record 4 of Set 3 | santa maria
# Processing Record 5 of Set 3 | san patricio
# Processing Record 6 of Set 3 | hofn
# Processing Record 7 of Set 3 | norman wells
# Processing Record 8 of Set 3 | puerto colombia
# Processing Record 9 of Set 3 | sentyabrskiy
# City not found. Skipping
# Processing Record 10 of Set 3 | severo-kurilsk
# Processing Record 11 of Set 3 | puerto princesa
# Processing Record 12 of Set 3 | lyman
# Processing Record 13 of Set 3 | deputatskiy
# Processing Record 14 of Set 3 | palu
# Processing Record 15 of Set 3 | krasnoselkup
# Processing Record 16 of Set 3 | vila franca do campo
# Processing Record 17 of Set 3 | longyearbyen
# Processing Record 18 of Set 3 | luderitz
# Processing Record 19 of Set 3 | college
# Processing Record 20 of Set 3 | bengkulu
# Processing Record 21 of Set 3 | ust-kuyga
# Processing Record 22 of Set 3 | dipkarpaz
# City not found. Skipping
# Processing Record 23 of Set 3 | praia
# Processing Record 24 of Set 3 | dikson
# Processing Record 25 of Set 3 | phan thiet
# Processing Record 26 of Set 3 | grindavik
# Processing Record 27 of Set 3 | xai-xai
# Processing Record 28 of Set 3 | tiksi
# Processing Record 29 of Set 3 | vaini
# Processing Record 30 of Set 3 | mys shmidta
# City not found. Skipping
# Processing Record 31 of Set 3 | yellowknife
# Processing Record 32 of Set 3 | taraz
# Processing Record 33 of Set 3 | hambantota
# Processing Record 34 of Set 3 | auki
# Processing Record 35 of Set 3 | umzimvubu
# City not found. Skipping
# Processing Record 36 of Set 3 | louros
# Processing Record 37 of Set 3 | los llanos de aridane
# Processing Record 38 of Set 3 | saint augustine
# Processing Record 39 of Set 3 | faya
# Processing Record 40 of Set 3 | belushya guba
# City not found. Skipping
# Processing Record 41 of Set 3 | punta arenas
# Processing Record 42 of Set 3 | fort nelson
# Processing Record 43 of Set 3 | ancud
# Processing Record 44 of Set 3 | luau
# Processing Record 45 of Set 3 | pemangkat
# Processing Record 46 of Set 3 | palabuhanratu
# City not found. Skipping
# Processing Record 47 of Set 3 | hasaki
# Processing Record 48 of Set 3 | antsohihy
# Processing Record 49 of Set 3 | kodiak
# Processing Record 50 of Set 3 | broken hill
# Processing Record 1 of Set 4 | saskylakh
# Processing Record 2 of Set 4 | esperance
# Processing Record 3 of Set 4 | mirnyy
# Processing Record 4 of Set 4 | ayna
# Processing Record 5 of Set 4 | bijie
# Processing Record 6 of Set 4 | sunbury
# Processing Record 7 of Set 4 | ballina
# Processing Record 8 of Set 4 | iqaluit
# Processing Record 9 of Set 4 | castro
# Processing Record 10 of Set 4 | vaitupu
# City not found. Skipping
# Processing Record 11 of Set 4 | seda
# Processing Record 12 of Set 4 | mitsamiouli
# Processing Record 13 of Set 4 | sao filipe
# Processing Record 14 of Set 4 | gamba
# Processing Record 15 of Set 4 | san cristobal
# Processing Record 16 of Set 4 | sibolga
# Processing Record 17 of Set 4 | codrington
# Processing Record 18 of Set 4 | springbok
# Processing Record 19 of Set 4 | nikolskoye
# Processing Record 20 of Set 4 | sokoni
# Processing Record 21 of Set 4 | yerbogachen
# Processing Record 22 of Set 4 | provideniya
# Processing Record 23 of Set 4 | jizan
# Processing Record 24 of Set 4 | soyo
# Processing Record 25 of Set 4 | pangnirtung
# Processing Record 26 of Set 4 | narsaq
# Processing Record 27 of Set 4 | yagodnoye
# Processing Record 28 of Set 4 | hami
# Processing Record 29 of Set 4 | weymouth
# Processing Record 30 of Set 4 | redmond
# Processing Record 31 of Set 4 | batemans bay
# Processing Record 32 of Set 4 | kikerino
# Processing Record 33 of Set 4 | wajima
# Processing Record 34 of Set 4 | lebu
# Processing Record 35 of Set 4 | waipawa
# Processing Record 36 of Set 4 | atotonilquillo
# Processing Record 37 of Set 4 | healesville
# Processing Record 38 of Set 4 | nizhniy odes
# Processing Record 39 of Set 4 | seoul
# Processing Record 40 of Set 4 | araguatins
# City not found. Skipping
# Processing Record 41 of Set 4 | manggar
# Processing Record 42 of Set 4 | mayo
# Processing Record 43 of Set 4 | isangel
# Processing Record 44 of Set 4 | marawi
# Processing Record 45 of Set 4 | polyarnyy
# Processing Record 46 of Set 4 | havoysund
# Processing Record 47 of Set 4 | plettenberg bay
# Processing Record 48 of Set 4 | siyabuswa
# Processing Record 49 of Set 4 | nivala
# Processing Record 50 of Set 4 | santa rosalia
# Processing Record 1 of Set 5 | aripuana
# Processing Record 2 of Set 5 | necochea
# Processing Record 3 of Set 5 | arraial do cabo
# Processing Record 4 of Set 5 | bethel
# Processing Record 5 of Set 5 | madina
# Processing Record 6 of Set 5 | bambous virieux
# Processing Record 7 of Set 5 | vagur
# Processing Record 8 of Set 5 | kegayli
# City not found. Skipping
# Processing Record 9 of Set 5 | chuy
# Processing Record 10 of Set 5 | tunceli
# Processing Record 11 of Set 5 | alice springs
# Processing Record 12 of Set 5 | yulara
# Processing Record 13 of Set 5 | contagem
# Processing Record 14 of Set 5 | mujiayingzi
# Processing Record 15 of Set 5 | upernavik
# Processing Record 16 of Set 5 | kavaratti
# Processing Record 17 of Set 5 | dongsheng
# Processing Record 18 of Set 5 | nizhniy kuranakh
# Processing Record 19 of Set 5 | hamilton
# Processing Record 20 of Set 5 | attawapiskat
# City not found. Skipping
# Processing Record 21 of Set 5 | lavrentiya
# Processing Record 22 of Set 5 | waterloo
# Processing Record 23 of Set 5 | raga
# Processing Record 24 of Set 5 | mindelo
# Processing Record 25 of Set 5 | faanui
# Processing Record 26 of Set 5 | zheleznodorozhnyy
# Processing Record 27 of Set 5 | frederick
# Processing Record 28 of Set 5 | mahadday weyne
# City not found. Skipping
# Processing Record 29 of Set 5 | new norfolk
# Processing Record 30 of Set 5 | nisia floresta
# Processing Record 31 of Set 5 | salto
# Processing Record 32 of Set 5 | araua
# Processing Record 33 of Set 5 | roald
# Processing Record 34 of Set 5 | shimoda
# Processing Record 35 of Set 5 | dawei
# Processing Record 36 of Set 5 | tumannyy
# City not found. Skipping
# Processing Record 37 of Set 5 | barawe
# City not found. Skipping
# Processing Record 38 of Set 5 | kommunarka
# Processing Record 39 of Set 5 | praya
# Processing Record 40 of Set 5 | sao joao da barra
# Processing Record 41 of Set 5 | road town
# Processing Record 42 of Set 5 | grootfontein
# Processing Record 43 of Set 5 | porirua
# Processing Record 44 of Set 5 | itarema
# Processing Record 45 of Set 5 | alekseyevsk
# Processing Record 46 of Set 5 | dhidhdhoo
# Processing Record 47 of Set 5 | kaduy
# Processing Record 48 of Set 5 | sokoto
# Processing Record 49 of Set 5 | vryburg
# Processing Record 50 of Set 5 | smithers
# Processing Record 1 of Set 6 | mawlaik
# Processing Record 2 of Set 6 | vao
# Processing Record 3 of Set 6 | camacha
# Processing Record 4 of Set 6 | bagdarin
# Processing Record 5 of Set 6 | livingstone
# Processing Record 6 of Set 6 | bhuj
# Processing Record 7 of Set 6 | nome
# Processing Record 8 of Set 6 | qaqortoq
# Processing Record 9 of Set 6 | moron
# Processing Record 10 of Set 6 | keflavik
# Processing Record 11 of Set 6 | cherskiy
# Processing Record 12 of Set 6 | batagay-alyta
# Processing Record 13 of Set 6 | san policarpo
# Processing Record 14 of Set 6 | shieli
# Processing Record 15 of Set 6 | mitu
# Processing Record 16 of Set 6 | lorengau
# Processing Record 17 of Set 6 | salalah
# Processing Record 18 of Set 6 | buraydah
# Processing Record 19 of Set 6 | cururupu
# Processing Record 20 of Set 6 | samana
# Processing Record 21 of Set 6 | port hardy
# Processing Record 22 of Set 6 | leninsk
# Processing Record 23 of Set 6 | samarai
# Processing Record 24 of Set 6 | meulaboh
# Processing Record 25 of Set 6 | caiaponia
# Processing Record 26 of Set 6 | bose
# Processing Record 27 of Set 6 | lovozero
# Processing Record 28 of Set 6 | torbay
# Processing Record 29 of Set 6 | balkanabat
# Processing Record 30 of Set 6 | falealupo
# City not found. Skipping
# Processing Record 31 of Set 6 | lagoa
# Processing Record 32 of Set 6 | sirohi
# Processing Record 33 of Set 6 | saint-francois
# Processing Record 34 of Set 6 | karlskoga
# Processing Record 35 of Set 6 | labuhan
# Processing Record 36 of Set 6 | savignano sul rubicone
# Processing Record 37 of Set 6 | twin falls
# Processing Record 38 of Set 6 | caravelas
# Processing Record 39 of Set 6 | semey
# Processing Record 40 of Set 6 | sistranda
# Processing Record 41 of Set 6 | olinda
# Processing Record 42 of Set 6 | klaksvik
# Processing Record 43 of Set 6 | westport
# Processing Record 44 of Set 6 | port macquarie
# Processing Record 45 of Set 6 | touros
# Processing Record 46 of Set 6 | sorland
# Processing Record 47 of Set 6 | acajutla
# Processing Record 48 of Set 6 | houston
# Processing Record 49 of Set 6 | saleaula
# City not found. Skipping
# Processing Record 50 of Set 6 | galiwinku
# City not found. Skipping
# Processing Record 1 of Set 7 | haines junction
# Processing Record 2 of Set 7 | shenjiamen
# Processing Record 3 of Set 7 | tilichiki
# Processing Record 4 of Set 7 | ternate
# Processing Record 5 of Set 7 | bubaque
# Processing Record 6 of Set 7 | cascais
# Processing Record 7 of Set 7 | lengshuitan
# Processing Record 8 of Set 7 | tetiz
# Processing Record 9 of Set 7 | umba
# Processing Record 10 of Set 7 | chokurdakh
# Processing Record 11 of Set 7 | andra
# Processing Record 12 of Set 7 | playa del carmen
# Processing Record 13 of Set 7 | dingle
# Processing Record 14 of Set 7 | fortuna
# Processing Record 15 of Set 7 | half moon bay
# Processing Record 16 of Set 7 | vysokogornyy
# Processing Record 17 of Set 7 | lakki marwat
# Processing Record 18 of Set 7 | upata
# Processing Record 19 of Set 7 | mbala
# Processing Record 20 of Set 7 | zarichne
# Processing Record 21 of Set 7 | aswan
# Processing Record 22 of Set 7 | great falls
# Processing Record 23 of Set 7 | fairbanks
# Processing Record 24 of Set 7 | gallup
# Processing Record 25 of Set 7 | lahaina
# Processing Record 26 of Set 7 | kimbe
# Processing Record 27 of Set 7 | kedrovyy
# Processing Record 28 of Set 7 | ikom
# Processing Record 29 of Set 7 | great yarmouth
# Processing Record 30 of Set 7 | nouadhibou
# Processing Record 31 of Set 7 | cockburn town
# Processing Record 32 of Set 7 | plouzane
# Processing Record 33 of Set 7 | saku
# Processing Record 34 of Set 7 | margate
# Processing Record 35 of Set 7 | karratha
# Processing Record 36 of Set 7 | kingaroy
# Processing Record 37 of Set 7 | portland
# Processing Record 38 of Set 7 | grand gaube
# Processing Record 39 of Set 7 | ngunguru
# Processing Record 40 of Set 7 | harper
# Processing Record 41 of Set 7 | lephepe
# City not found. Skipping
# Processing Record 42 of Set 7 | payson
# Processing Record 43 of Set 7 | valdemarpils
# Processing Record 44 of Set 7 | marcona
# City not found. Skipping
# Processing Record 45 of Set 7 | henties bay
# Processing Record 46 of Set 7 | bambanglipuro
# Processing Record 47 of Set 7 | boden
# Processing Record 48 of Set 7 | bokspits
# City not found. Skipping
# Processing Record 49 of Set 7 | crateus
# Processing Record 50 of Set 7 | kloulklubed
# Processing Record 1 of Set 8 | kirakira
# Processing Record 2 of Set 8 | atchison
# Processing Record 3 of Set 8 | san vicente
# Processing Record 4 of Set 8 | udachnyy
# Processing Record 5 of Set 8 | makakilo city
# Processing Record 6 of Set 8 | poum
# Processing Record 7 of Set 8 | krasavino
# Processing Record 8 of Set 8 | tautira
# Processing Record 9 of Set 8 | balangbalang
# Processing Record 10 of Set 8 | batagay
# Processing Record 11 of Set 8 | caxito
# Processing Record 12 of Set 8 | homer
# Processing Record 13 of Set 8 | cordoba
# Processing Record 14 of Set 8 | ponta delgada
# Processing Record 15 of Set 8 | ambilobe
# Processing Record 16 of Set 8 | losevo
# Processing Record 17 of Set 8 | andrews
# Processing Record 18 of Set 8 | husavik
# Processing Record 19 of Set 8 | matara
# Processing Record 20 of Set 8 | cabedelo
# Processing Record 21 of Set 8 | mamou
# Processing Record 22 of Set 8 | brae
# Processing Record 23 of Set 8 | griffith
# Processing Record 24 of Set 8 | te anau
# Processing Record 25 of Set 8 | paamiut
# Processing Record 26 of Set 8 | saldanha
# Processing Record 27 of Set 8 | guerrero negro
# Processing Record 28 of Set 8 | playas
# Processing Record 29 of Set 8 | wicklow
# Processing Record 30 of Set 8 | agde
# Processing Record 31 of Set 8 | atherton
# Processing Record 32 of Set 8 | borogontsy
# Processing Record 33 of Set 8 | kadykchan
# City not found. Skipping
# Processing Record 34 of Set 8 | lubao
# Processing Record 35 of Set 8 | oranjestad
# Processing Record 36 of Set 8 | villamontes
# Processing Record 37 of Set 8 | yulin
# Processing Record 38 of Set 8 | nagapattinam
# Processing Record 39 of Set 8 | bay roberts
# Processing Record 40 of Set 8 | mehamn
# Processing Record 41 of Set 8 | merauke
# Processing Record 42 of Set 8 | skibbereen
# Processing Record 43 of Set 8 | shuyskoye
# Processing Record 44 of Set 8 | qarqin
# Processing Record 45 of Set 8 | lompoc
# Processing Record 46 of Set 8 | fushun
# Processing Record 47 of Set 8 | waki
# Processing Record 48 of Set 8 | davila
# Processing Record 49 of Set 8 | shunyi
# Processing Record 50 of Set 8 | charapan
# Processing Record 1 of Set 9 | kamaishi
# Processing Record 2 of Set 9 | la ronge
# Processing Record 3 of Set 9 | komsomolskiy
# Processing Record 4 of Set 9 | dudinka
# Processing Record 5 of Set 9 | namibe
# Processing Record 6 of Set 9 | monrovia
# Processing Record 7 of Set 9 | adrar
# Processing Record 8 of Set 9 | yankton
# Processing Record 9 of Set 9 | ozernovskiy
# Processing Record 10 of Set 9 | tahta
# Processing Record 11 of Set 9 | botwood
# Processing Record 12 of Set 9 | svarstad
# Processing Record 13 of Set 9 | ewa beach
# Processing Record 14 of Set 9 | tombouctou
# Processing Record 15 of Set 9 | nelson bay
# Processing Record 16 of Set 9 | ondjiva
# Processing Record 17 of Set 9 | pierre
# Processing Record 18 of Set 9 | kalpi
# Processing Record 19 of Set 9 | barbar
# City not found. Skipping
# Processing Record 20 of Set 9 | excelsior springs
# Processing Record 21 of Set 9 | kenai
# Processing Record 22 of Set 9 | berekum
# Processing Record 23 of Set 9 | kang
# Processing Record 24 of Set 9 | pimenta bueno
# Processing Record 25 of Set 9 | sechura
# Processing Record 26 of Set 9 | maragogi
# Processing Record 27 of Set 9 | mumford
# Processing Record 28 of Set 9 | ardrossan
# Processing Record 29 of Set 9 | sidney
# Processing Record 30 of Set 9 | san martin
# Processing Record 31 of Set 9 | san jose
# Processing Record 32 of Set 9 | bilibino
# Processing Record 33 of Set 9 | bereznik
# Processing Record 34 of Set 9 | phan rang
# City not found. Skipping
# Processing Record 35 of Set 9 | cayenne
# Processing Record 36 of Set 9 | sao tome
# Processing Record 37 of Set 9 | norheimsund
# Processing Record 38 of Set 9 | bobcaygeon
# Processing Record 39 of Set 9 | luwuk
# Processing Record 40 of Set 9 | tallahassee
# Processing Record 41 of Set 9 | namtsy
# Processing Record 42 of Set 9 | marabba
# Processing Record 43 of Set 9 | palmer
# Processing Record 44 of Set 9 | bandarbeyla
# Processing Record 45 of Set 9 | mount isa
# Processing Record 46 of Set 9 | hit
# Processing Record 47 of Set 9 | mildura
# Processing Record 48 of Set 9 | khandbari
# Processing Record 49 of Set 9 | lata
# Processing Record 50 of Set 9 | menongue
# Processing Record 1 of Set 10 | kralendijk
# Processing Record 2 of Set 10 | verkhniy baskunchak
# Processing Record 3 of Set 10 | stabat
# Processing Record 4 of Set 10 | senanga
# Processing Record 5 of Set 10 | kruisfontein
# Processing Record 6 of Set 10 | karkaralinsk
# City not found. Skipping
# Processing Record 7 of Set 10 | igrim
# Processing Record 8 of Set 10 | pasighat
# Processing Record 9 of Set 10 | chapais
# Processing Record 10 of Set 10 | okhotsk
# Processing Record 11 of Set 10 | caraquet
# Processing Record 12 of Set 10 | ojinaga
# Processing Record 13 of Set 10 | cervo
# Processing Record 14 of Set 10 | vaitape
# Processing Record 15 of Set 10 | luan
# Processing Record 16 of Set 10 | sirnak
# Processing Record 17 of Set 10 | stromness
# Processing Record 18 of Set 10 | diphu
# Processing Record 19 of Set 10 | san quintin
# Processing Record 20 of Set 10 | belyy yar
# Processing Record 21 of Set 10 | pskov
# Processing Record 22 of Set 10 | tuatapere
# Processing Record 23 of Set 10 | magway
# Processing Record 24 of Set 10 | evensk
# Processing Record 25 of Set 10 | louisbourg
# City not found. Skipping
# Processing Record 26 of Set 10 | nemuro
# Processing Record 27 of Set 10 | bartica
# Processing Record 28 of Set 10 | barcelos
# Processing Record 29 of Set 10 | pavlodar
# Processing Record 30 of Set 10 | goderich
# Processing Record 31 of Set 10 | qaanaaq
# Processing Record 32 of Set 10 | tateyama
# Processing Record 33 of Set 10 | isiro
# Processing Record 34 of Set 10 | slave lake
# Processing Record 35 of Set 10 | ruatoria
# City not found. Skipping
# Processing Record 36 of Set 10 | tucuman
# Processing Record 37 of Set 10 | bougouni
# Processing Record 38 of Set 10 | padang
# Processing Record 39 of Set 10 | poya
# Processing Record 40 of Set 10 | mao
# Processing Record 41 of Set 10 | plaster rock
# Processing Record 42 of Set 10 | satitoa
# City not found. Skipping
# Processing Record 43 of Set 10 | punta umbria
# Processing Record 44 of Set 10 | pisco
# Processing Record 45 of Set 10 | nossa senhora da gloria
# Processing Record 46 of Set 10 | blonduos
# City not found. Skipping
# Processing Record 47 of Set 10 | majene
# Processing Record 48 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 10 | thomaston
# Processing Record 50 of Set 10 | andenes
# Processing Record 1 of Set 11 | coahuayana
# Processing Record 2 of Set 11 | stephenville
# Processing Record 3 of Set 11 | mountain home
# Processing Record 4 of Set 11 | visby
# Processing Record 5 of Set 11 | sisimiut
# Processing Record 6 of Set 11 | comodoro rivadavia
# Processing Record 7 of Set 11 | thanh hoa
# Processing Record 8 of Set 11 | port blair
# Processing Record 9 of Set 11 | hirado
# Processing Record 10 of Set 11 | kidal
# Processing Record 11 of Set 11 | dergachi
# Processing Record 12 of Set 11 | zabol
# Processing Record 13 of Set 11 | katsina
# Processing Record 14 of Set 11 | kupang
# Processing Record 15 of Set 11 | ketchikan
# Processing Record 16 of Set 11 | rosetta
# Processing Record 17 of Set 11 | birnin kebbi
# Processing Record 18 of Set 11 | chone
# Processing Record 19 of Set 11 | constitucion
# Processing Record 20 of Set 11 | huarmey
# Processing Record 21 of Set 11 | luwingu
# Processing Record 22 of Set 11 | naze
# Processing Record 23 of Set 11 | mountrath
# Processing Record 24 of Set 11 | mandapam
# Processing Record 25 of Set 11 | alausi
# Processing Record 26 of Set 11 | sakakah
# Processing Record 27 of Set 11 | rio gallegos
# Processing Record 28 of Set 11 | leningradskiy
# Processing Record 29 of Set 11 | jalu
# Processing Record 30 of Set 11 | sorgun
# Processing Record 31 of Set 11 | tamandare
# Processing Record 32 of Set 11 | egvekinot
# Processing Record 33 of Set 11 | khasan
# Processing Record 34 of Set 11 | port-gentil
# Processing Record 35 of Set 11 | seabra
# Processing Record 36 of Set 11 | burica
# City not found. Skipping
# Processing Record 37 of Set 11 | dalnerechensk
# Processing Record 38 of Set 11 | dunedin
# Processing Record 39 of Set 11 | ziarat
# Processing Record 40 of Set 11 | saint-joseph
# Processing Record 41 of Set 11 | sapa
# Processing Record 42 of Set 11 | divnomorskoye
# Processing Record 43 of Set 11 | madison
# Processing Record 44 of Set 11 | lircay
# Processing Record 45 of Set 11 | alta floresta
# Processing Record 46 of Set 11 | zyryanskoye
# Processing Record 47 of Set 11 | kalinovskaya
# Processing Record 48 of Set 11 | sagua la grande
# Processing Record 49 of Set 11 | vermilion
# Processing Record 50 of Set 11 | palmares do sul
# Processing Record 1 of Set 12 | huilong
# Processing Record 2 of Set 12 | ust-omchug
# Processing Record 3 of Set 12 | nayoro
# Processing Record 4 of Set 12 | raton
# Processing Record 5 of Set 12 | takaka
# Processing Record 6 of Set 12 | aksu
# Processing Record 7 of Set 12 | mayumba
# Processing Record 8 of Set 12 | pathein
# Processing Record 9 of Set 12 | fallon
# Processing Record 10 of Set 12 | vreed en hoop
# City not found. Skipping
# Processing Record 11 of Set 12 | susangerd
# Processing Record 12 of Set 12 | san carlos de bariloche
# Processing Record 13 of Set 12 | zhigansk
# Processing Record 14 of Set 12 | khani
# Processing Record 15 of Set 12 | itaquyry
# Processing Record 16 of Set 12 | marshall
# Processing Record 17 of Set 12 | banjar
# Processing Record 18 of Set 12 | oeiras
# Processing Record 19 of Set 12 | beloha
# Processing Record 20 of Set 12 | ginda
# Processing Record 21 of Set 12 | cotonou
# Processing Record 22 of Set 12 | atambua
# Processing Record 23 of Set 12 | honiara
# Processing Record 24 of Set 12 | sorvag
# City not found. Skipping
# Processing Record 25 of Set 12 | sambava
# Processing Record 26 of Set 12 | kieta
# Processing Record 27 of Set 12 | moranbah
# Processing Record 28 of Set 12 | boda
# Processing Record 29 of Set 12 | berlevag
# Processing Record 30 of Set 12 | sydney mines
# Processing Record 31 of Set 12 | mishan
# Processing Record 32 of Set 12 | newtown saint boswells
# Processing Record 33 of Set 12 | baiao
# Processing Record 34 of Set 12 | mangan
# Processing Record 35 of Set 12 | manakara
# Processing Record 36 of Set 12 | chushan
# Processing Record 37 of Set 12 | paralimni
# Processing Record 38 of Set 12 | bolungarvik
# City not found. Skipping
# Processing Record 39 of Set 12 | aketi
# Processing Record 40 of Set 12 | nioki
# Processing Record 41 of Set 12 | awbari
# Processing Record 42 of Set 12 | bardiyah
# Processing Record 43 of Set 12 | haibowan
# City not found. Skipping
# Processing Record 44 of Set 12 | yar-sale
# Processing Record 45 of Set 12 | guspini
# Processing Record 46 of Set 12 | spokane
# Processing Record 47 of Set 12 | sernur
# Processing Record 48 of Set 12 | fereydunshahr
# Processing Record 49 of Set 12 | zachagansk
# City not found. Skipping
# Processing Record 50 of Set 12 | hailey
# Processing Record 1 of Set 13 | gotsu
# Processing Record 2 of Set 13 | hwange
# Processing Record 3 of Set 13 | sulangan
# Processing Record 4 of Set 13 | ngukurr
# City not found. Skipping
# Processing Record 5 of Set 13 | sumbawa
# City not found. Skipping
# Processing Record 6 of Set 13 | neiafu
# Processing Record 7 of Set 13 | lazaro cardenas
# Processing Record 8 of Set 13 | gagino
# Processing Record 9 of Set 13 | andarab
# City not found. Skipping
# Processing Record 10 of Set 13 | kutum
# Processing Record 11 of Set 13 | mkushi
# Processing Record 12 of Set 13 | altay
# Processing Record 13 of Set 13 | cam ranh
# Processing Record 14 of Set 13 | luganville
# Processing Record 15 of Set 13 | salur
# Processing Record 16 of Set 13 | port hedland
# Processing Record 17 of Set 13 | artesia
# Processing Record 18 of Set 13 | vila velha
# Processing Record 19 of Set 13 | straldza
# City not found. Skipping
# Processing Record 20 of Set 13 | dharchula
# Processing Record 21 of Set 13 | karauzyak
# City not found. Skipping
# Processing Record 22 of Set 13 | malwan
# City not found. Skipping
# Processing Record 23 of Set 13 | fatehabad
# Processing Record 24 of Set 13 | adre
# Processing Record 25 of Set 13 | lingao
# Processing Record 26 of Set 13 | eirunepe
# Processing Record 27 of Set 13 | sigli
# Processing Record 28 of Set 13 | asyut
# Processing Record 29 of Set 13 | havelock
# Processing Record 30 of Set 13 | novyy urgal
# Processing Record 31 of Set 13 | saint-augustin
# Processing Record 32 of Set 13 | karasjok
# Processing Record 33 of Set 13 | progreso
# Processing Record 34 of Set 13 | katherine
# Processing Record 35 of Set 13 | mabaruma
# Processing Record 36 of Set 13 | natchitoches
# Processing Record 37 of Set 13 | nguiu
# City not found. Skipping
# Processing Record 38 of Set 13 | monte cristi
# City not found. Skipping
# Processing Record 39 of Set 13 | nampula
# Processing Record 40 of Set 13 | burnie
# Processing Record 41 of Set 13 | pacific grove
# Processing Record 42 of Set 13 | emba
# Processing Record 43 of Set 13 | scarborough
# Processing Record 44 of Set 13 | leshukonskoye
# Processing Record 45 of Set 13 | tahoua
# Processing Record 46 of Set 13 | ornskoldsvik
# Processing Record 47 of Set 13 | boa vista
# Processing Record 48 of Set 13 | mitchell
# Processing Record 49 of Set 13 | roros
# Processing Record 50 of Set 13 | quzhou
# Processing Record 1 of Set 14 | avera
# Processing Record 2 of Set 14 | tromso
# Processing Record 3 of Set 14 | buarcos
# Processing Record 4 of Set 14 | san carlos
# Processing Record 5 of Set 14 | bouar
# Processing Record 6 of Set 14 | abha
# Processing Record 7 of Set 14 | ahipara
# Processing Record 8 of Set 14 | moose factory
# Processing Record 9 of Set 14 | oltu
# Processing Record 10 of Set 14 | kununurra
# Processing Record 11 of Set 14 | coos bay
# Processing Record 12 of Set 14 | halalo
# City not found. Skipping
# Processing Record 13 of Set 14 | mullaitivu
# City not found. Skipping
# Processing Record 14 of Set 14 | aykhal
# Processing Record 15 of Set 14 | sinegorye
# Processing Record 16 of Set 14 | ostersund
# Processing Record 17 of Set 14 | yenagoa
# Processing Record 18 of Set 14 | broome
# Processing Record 19 of Set 14 | baruun-urt
# Processing Record 20 of Set 14 | inyonga
# Processing Record 21 of Set 14 | seymchan
# Processing Record 22 of Set 14 | thinadhoo
# Processing Record 23 of Set 14 | nyurba
# Processing Record 24 of Set 14 | george town
# Processing Record 25 of Set 14 | labutta
# City not found. Skipping
# Processing Record 26 of Set 14 | pangody
# Processing Record 27 of Set 14 | bardsir
# Processing Record 28 of Set 14 | alyangula
# Processing Record 29 of Set 14 | temir
# Processing Record 30 of Set 14 | ahuimanu
# Processing Record 31 of Set 14 | bilma
# Processing Record 32 of Set 14 | arlit
# Processing Record 33 of Set 14 | jumla
# Processing Record 34 of Set 14 | hihifo
# City not found. Skipping
# Processing Record 35 of Set 14 | vostok
# Processing Record 36 of Set 14 | vinh
# Processing Record 37 of Set 14 | wasilla
# Processing Record 38 of Set 14 | rodrigues alves
# Processing Record 39 of Set 14 | sobolevo
# Processing Record 40 of Set 14 | pacifica
# Processing Record 41 of Set 14 | chunskiy
# Processing Record 42 of Set 14 | okha
# Processing Record 43 of Set 14 | lasa
# Processing Record 44 of Set 14 | nantucket
# Processing Record 45 of Set 14 | conceicao do araguaia
# Processing Record 46 of Set 14 | ulaangom
# Processing Record 47 of Set 14 | diffa
# Processing Record 48 of Set 14 | roebourne
# Processing Record 49 of Set 14 | nioro
# Processing Record 50 of Set 14 | charters towers
# Processing Record 1 of Set 15 | cozumel
# Processing Record 2 of Set 15 | weihe
# Processing Record 3 of Set 15 | yarmouth
# Processing Record 4 of Set 15 | cartagena
# Processing Record 5 of Set 15 | shakawe
# Processing Record 6 of Set 15 | joao pinheiro
# Processing Record 7 of Set 15 | sumkino
# Processing Record 8 of Set 15 | trat
# Processing Record 9 of Set 15 | teluk nibung
# Processing Record 10 of Set 15 | tavistock
# Processing Record 11 of Set 15 | coquimbo
# Processing Record 12 of Set 15 | nautla
# Processing Record 13 of Set 15 | brewster
# Processing Record 14 of Set 15 | silivri
# Processing Record 15 of Set 15 | teya
# Processing Record 16 of Set 15 | benjamin constant
# Processing Record 17 of Set 15 | luanda
# Processing Record 18 of Set 15 | taketa
# Processing Record 19 of Set 15 | san miguelito
# Processing Record 20 of Set 15 | emerald
# Processing Record 21 of Set 15 | linhares
# Processing Record 22 of Set 15 | santa margherita ligure
# Processing Record 23 of Set 15 | acapulco
# Processing Record 24 of Set 15 | mandalgovi
# Processing Record 25 of Set 15 | kuusamo
# Processing Record 26 of Set 15 | litovko
# Processing Record 27 of Set 15 | orizatlan
# -----------------------------
# Data Retrieval Complete
# -----------------------------
